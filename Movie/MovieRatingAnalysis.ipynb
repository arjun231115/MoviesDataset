# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/arjunpatel/Desktop/Movie'

# %%
movie = pd.read_csv('movie.csv')

# %%
movie
# Out:
#                                    Film      Genre  Rotten Tomatoes Ratings %  \
# 0                 (500) Days of Summer      Comedy                         87
# 1                           10,000 B.C.  Adventure                          9
# 2                            12 Rounds      Action                         30
# 3                             127 Hours  Adventure                         93
# 4                             17 Again      Comedy                         55
# 5                                  2012     Action                         39
# 6                            27 Dresses     Comedy                         40
# 7                      30 Days of Night     Horror                         50
# 8                    30 Minutes or Less     Comedy                         43
# 9                                 50/50     Comedy                         93
# 10                           88 Minutes      Drama                          5
# ...

# %% [markdown]
# m

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns = ['Film','Genre','CriticRating','AudienceRating','BudgetMillion','Year']

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movie.Film =movie.Film.astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillion     559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movie.Genre=movie.Genre.astype('category')

# %%
movie.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
# 5         Action
# 6         Comedy
# 7         Horror
# 8         Comedy
# 9         Comedy
# 10         Drama
# 11         Drama
# 12        Horror
# 13         Drama
# 14        Comedy
# 15        Action
# 16       Romance
# 17        Comedy
# 18         Drama
# 19     Adventure
# 20        Horror
# 21     Adventure
# 22        Comedy
# 23         Drama
# 24     Adventure
# 25      Thriller
# 26         Drama
# 27         Drama
# 28        Horror
# 29        Action
#          ...
# 529        Drama
# 530       Action
# 531       Action
# 532        Drama
# 533       Comedy
# 534        Drama
# 535       Comedy
# 536       Comedy
# 537       Comedy
# 538       Comedy
# 539       Comedy
# 540    Adventure
# 541        Drama
# 542       Action
# 543       Comedy
# 544       Comedy
# 545        Drama
# 546       Action
# 547       Action
# 548    Adventure
# 549       Comedy
# ...

# %%
movie.Year=movie.Year.astype('category')

# %%
movie.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
# 5      2009
# 6      2008
# 7      2007
# 8      2011
# 9      2011
# 10     2007
# 11     2011
# 12     2010
# 13     2009
# 14     2011
# 15     2011
# 16     2007
# 17     2009
# 18     2011
# 19     2010
# 20     2007
# 21     2009
# 22     2009
# 23     2010
# 24     2009
# 25     2007
# 26     2009
# 27     2011
# 28     2011
# 29     2008
#        ...
# 529    2011
# 530    2011
# 531    2009
# 532    2011
# 533    2011
# 534    2007
# 535    2008
# 536    2008
# 537    2011
# 538    2009
# 539    2010
# 540    2009
# 541    2009
# 542    2009
# 543    2010
# 544    2007
# 545    2010
# 546    2009
# 547    2011
# 548    2009
# 549    2008
# 550    2010
# 551    2010
# 552    2008
# 553    2010
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movie.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movie.Year.cat.categories
# Out:
# Int64Index([2007, 2008, 2009, 2010, 2011], dtype='int64')

# %%
movie.Film.cat.categories
# Out:
# Index(['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours',
#        '17 Again ', '2012', '27 Dresses', '30 Days of Night',
#        '30 Minutes or Less', '50/50',
#        ...
#        'Yes Man', 'Yogi Bear', 'You Again', 'You Don't Mess with the Zohan',
#        'You Will Meet a Tall Dark Stranger', 'Your Highness',
#        'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper'],
#       dtype='object', length=559)

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion
# count    559.000000      559.000000     559.000000
# mean      47.309481       58.744186      50.236136
# std       26.413091       16.826887      48.731817
# min        0.000000        0.000000       0.000000
# 25%       25.000000       47.000000      20.000000
# 50%       46.000000       58.000000      35.000000
# 75%       70.000000       72.000000      65.000000
# max       97.000000       96.000000     300.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
s=sns.jointplot(data=movie,x='CriticRating',y='AudienceRating')

# %%
s=sns.jointplot(data=movie,x='CriticRating',y='AudienceRating',kind="hex")

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillion     559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion
# count    559.000000      559.000000     559.000000
# mean      47.309481       58.744186      50.236136
# std       26.413091       16.826887      48.731817
# min        0.000000        0.000000       0.000000
# 25%       25.000000       47.000000      20.000000
# 50%       46.000000       58.000000      35.000000
# 75%       70.000000       72.000000      65.000000
# max       97.000000       96.000000     300.000000

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movie.Film.cat.categories
# Out:
# Index(['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours',
#        '17 Again ', '2012', '27 Dresses', '30 Days of Night',
#        '30 Minutes or Less', '50/50',
#        ...
#        'Yes Man', 'Yogi Bear', 'You Again', 'You Don't Mess with the Zohan',
#        'You Will Meet a Tall Dark Stranger', 'Your Highness',
#        'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper'],
#       dtype='object', length=559)

# %%
sns.set_style("darkgrid")
f=sns.distplot(movie.CriticRating,bins=50)

# %%
sns.set_style("darkgrid")
m=plt.hist(data=movie,x='CriticRating',bins=40)

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillion',
#        'Year'],
#       dtype='object')

# %%
plt.hist(movie.BudgetMillion)
plt.show()

# %%
plt.hist(movie[movie.Genre == 'Action'].BudgetMillion,bins=15)
plt.hist(movie[movie.Genre == 'Drama'].BudgetMillion,bins=15)
plt.hist(movie[movie.Genre == 'Thriller'].BudgetMillion,bins=15)
plt.hist(movie[movie.Genre == 'Comedy'].BudgetMillion,bins=15)


plt.show()

# %%
plt.hist([movie[movie.Genre == 'Action'].BudgetMillion,
         movie[movie.Genre == 'Drama'].BudgetMillion],bins=15,stacked=True)
plt.show()

# %%
plt.show()

# %%
 movie.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
list1=[]
mylabel=[]
for gen in movie.Genre.cat.categories:
    list1.append(movie[movie.Genre == gen].BudgetMillion)
    mylabel.append(gen)
h=plt.hist(list1,bins=15,stacked=True,rwidth=2,label=mylabel)
plt.legend()
plt.show()

# %%
f=sns.kdeplot(movie.CriticRating,movie.AudienceRating,shade=True,shade_lowest=False,cmap='Reds')

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillion     559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movie.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
j = sns.lmplot(data=movie,x='CriticRating',y='AudienceRating',fit_reg=False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('dark')
k1=sns.kdeplot(movie.BudgetMillion,movie.AudienceRating)

# %%
k1=sns.kdeplot(movie.BudgetMillion,movie.CriticRating)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f, axes = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)
k1=sns.kdeplot(movie.BudgetMillion,movie.AudienceRating,ax=axes[0,1])
k2=sns.kdeplot(movie.BudgetMillion,movie.CriticRating,ax=axes[0,0])
k3=sns.kdeplot(movie.CriticRating,movie.AudienceRating,ax=axes[1,0])
k4=sns.kdeplot(movie.Year,movie.BudgetMillion,ax=axes[1,1])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
k4=sns.kdeplot(movie.Year,movie.BudgetMillion)

# %%
k4

# %%
# Craeting Facit Grid

# %%
g=sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')

# %%
g=sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=1,edgecolor='red')
g = g.map(plt.scatter,'CriticRating','AudienceRating',**kws)

# %%
g=sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
g.set(xlim=(0,100),ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c='gray',ls='--') 
g.add_legend()

# %%
#MOVIES GROSS DATA SET

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
mov = pd.read_csv('MovieGross.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x88 in position 14: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-10-99ca3bf1fa21> in <module>
# ----> 1 mov = pd.read_csv('MovieGross.csv')
#
# ...
